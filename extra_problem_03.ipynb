# %% [markdown]
# <a href="https://colab.research.google.com/github/Tharun-sk07/DAA/blob/main/extra_problem_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def kmp_trace(text, pattern):
    lps = compute_lps(pattern)
    n = len(text)
    m = len(pattern)
    i = 0
    j = 0

    print("Tracing text search:")
    while i < n:
        print(f"Comparing text[{i}]='{text[i]}' and pattern[{j}]='{pattern[j]}'")
        if text[i] == pattern[j]:
            i += 1
            j += 1
            if j == m:
                print(f"-> Match found at index {i - j}!")
                j = lps[j - 1]
        else:
            if j != 0:
                print(f"-> Mismatch! Shift pattern using lps[{j-1}] = {lps[j-1]}")
                j = lps[j - 1]
            else:
                print(f"-> Mismatch! Advance text index i to {i+1}")
                i += 1
